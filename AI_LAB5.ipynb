# %%
print("Akanksha Singa")
print("USN: 1BM22CS027")
import random
from math import exp
import time
from copy import deepcopy

N_QUEENS = 8
TEMPERATURE = 100

def threat_calculate(n):
    '''Combination formula for calculating attacking pairs.'''
    if n < 2:
        return 0
    return (n - 1) * n / 2

def create_board(n):
    '''Create a chessboard with one queen per column, randomly placed.'''
    chess_board = {}
    temp = list(range(n))
    random.shuffle(temp)  # Shuffle to randomize the initial board
    for column in range(n):
        chess_board[column] = temp[column]
    return chess_board

def cost(chess_board):
    '''Calculate the number of attacking queen pairs.'''
    threat = 0
    m_chessboard = {}
    a_chessboard = {}

    for column in chess_board:
        temp_m = column - chess_board[column]
        temp_a = column + chess_board[column]
        m_chessboard[temp_m] = m_chessboard.get(temp_m, 0) + 1
        a_chessboard[temp_a] = a_chessboard.get(temp_a, 0) + 1

    for count in m_chessboard.values():
        threat += threat_calculate(count)
    for count in a_chessboard.values():
        threat += threat_calculate(count)

    return threat

def print_chess_board(board, count):
    '''Print the chess board.'''
    print("Iteration:", count)
    for row in range(N_QUEENS):
        line = ""
        for col in range(N_QUEENS):
            if board[col] == row:
                line += "Q "
            else:
                line += ". "
        print(line)
    print("\n")

def simulated_annealing():
    '''Simulated Annealing for N-Queens Problem.'''
    solution_found = False
    answer = create_board(N_QUEENS)
    cost_answer = cost(answer)
    count = 0

    t = TEMPERATURE
    cooling_rate = 0.99

    while t > 0:
        count += 1
        t *= cooling_rate

        # Generate a new successor by swapping two randomly chosen columns
        successor = deepcopy(answer)
        index_1, index_2 = random.sample(range(N_QUEENS), 2)
        successor[index_1], successor[index_2] = successor[index_2], successor[index_1]

        successor_cost = cost(successor)
        delta = successor_cost - cost_answer

        # Calculate the probability of accepting the successor
        if delta < 0:
            acceptance_probability = 1.0
        else:
            acceptance_probability = exp(-delta / t)

        # Decide whether to accept the new state
        if delta < 0 or random.uniform(0, 1) < acceptance_probability:
            answer = deepcopy(successor)
            cost_answer = successor_cost

        # Print board, cost, and probability at each iteration
        print(f"Iteration {count}, Temperature: {t:.4f}")
        print("Board configuration:")
        print_chess_board(answer, count)
        print(f"Current cost: {cost_answer}")
        print(f"Acceptance probability: {acceptance_probability:.4f}\n")

        # Check if solution is found
        if cost_answer == 0:
            solution_found = True
            print("Solution found!")
            print_chess_board(answer, count)
            break

    if not solution_found:
        print("Failed to find a solution.")

def main():
    start = time.time()
    simulated_annealing()
    print("Runtime in seconds:", time.time() - start)

if __name__ == "__main__":
    main()
# Out:
# Akanksha Singa
# USN: 1BM22CS027
# Iteration 1, Temperature: 99.0000
# Board configuration:
# Iteration: 1
# . . . Q . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# . . . . Q . . .
# . . Q . . . . .
#
#
# Current cost: 8.0
# Acceptance probability: 1.0000
#
# Iteration 2, Temperature: 98.0100
# Board configuration:
# Iteration: 2
# . . . Q . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 3, Temperature: 97.0299
# Board configuration:
# Iteration: 3
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 4, Temperature: 96.0596
# Board configuration:
# Iteration: 4
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9896
#
# Iteration 5, Temperature: 95.0990
# Board configuration:
# Iteration: 5
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 6, Temperature: 94.1480
# Board configuration:
# Iteration: 6
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9790
#
# Iteration 7, Temperature: 93.2065
# Board configuration:
# Iteration: 7
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# Q . . . . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 8, Temperature: 92.2745
# Board configuration:
# Iteration: 8
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . Q . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 9, Temperature: 91.3517
# Board configuration:
# Iteration: 9
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 10, Temperature: 90.4382
# Board configuration:
# Iteration: 10
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9674
#
# Iteration 11, Temperature: 89.5338
# Board configuration:
# Iteration: 11
# . . . . Q . . .
# . . . Q . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9889
#
# Iteration 12, Temperature: 88.6385
# Board configuration:
# Iteration: 12
# . . . Q . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 13, Temperature: 87.7521
# Board configuration:
# Iteration: 13
# . . . Q . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9887
#
# Iteration 14, Temperature: 86.8746
# Board configuration:
# Iteration: 14
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 15, Temperature: 86.0058
# Board configuration:
# Iteration: 15
# . . . Q . . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.9770
#
# Iteration 16, Temperature: 85.1458
# Board configuration:
# Iteration: 16
# . Q . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 17, Temperature: 84.2943
# Board configuration:
# Iteration: 17
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 18, Temperature: 83.4514
# Board configuration:
# Iteration: 18
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 19, Temperature: 82.6169
# Board configuration:
# Iteration: 19
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# Q . . . . . . .
# . Q . . . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9761
#
# Iteration 20, Temperature: 81.7907
# Board configuration:
# Iteration: 20
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# Q . . . . . . .
# . Q . . . . . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.9758
#
# Iteration 21, Temperature: 80.9728
# Board configuration:
# Iteration: 21
# . . . . . Q . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . Q . . . . . .
#
#
# Current cost: 8.0
# Acceptance probability: 1.0000
#
# Iteration 22, Temperature: 80.1631
# Board configuration:
# Iteration: 22
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 23, Temperature: 79.3614
# Board configuration:
# Iteration: 23
# . . . . . Q . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
#
#
# Current cost: 4.0
# Acceptance probability: 0.9875
#
# Iteration 24, Temperature: 78.5678
# Board configuration:
# Iteration: 24
# Q . . . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 25, Temperature: 77.7821
# Board configuration:
# Iteration: 25
# Q . . . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 26, Temperature: 77.0043
# Board configuration:
# Iteration: 26
# . Q . . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . . Q . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.9494
#
# Iteration 27, Temperature: 76.2343
# Board configuration:
# Iteration: 27
# . . . . . . Q .
# . . . . Q . . .
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . . Q . .
#
#
# Current cost: 11.0
# Acceptance probability: 0.9614
#
# Iteration 28, Temperature: 75.4719
# Board configuration:
# Iteration: 28
# . . . . . . Q .
# . . . . Q . . .
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . Q . .
#
#
# Current cost: 8.0
# Acceptance probability: 1.0000
#
# Iteration 29, Temperature: 74.7172
# Board configuration:
# Iteration: 29
# . . . Q . . . .
# . . . . Q . . .
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . . . Q . .
#
#
# Current cost: 10.0
# Acceptance probability: 0.9736
#
# Iteration 30, Temperature: 73.9700
# Board configuration:
# Iteration: 30
# . . . . . . Q .
# . . . . Q . . .
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . Q . .
#
#
# Current cost: 8.0
# Acceptance probability: 1.0000
#
# Iteration 31, Temperature: 73.2303
# Board configuration:
# Iteration: 31
# . . . . . . Q .
# . . . . Q . . .
# Q . . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
#
#
# Current cost: 7.0
# Acceptance probability: 1.0000
#
# Iteration 32, Temperature: 72.4980
# Board configuration:
# Iteration: 32
# . . . . . . Q .
# . . . . Q . . .
# Q . . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
#
#
# Current cost: 9.0
# Acceptance probability: 0.9728
#
# Iteration 33, Temperature: 71.7731
# Board configuration:
# Iteration: 33
# . . . . . . Q .
# . . . . Q . . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 34, Temperature: 71.0553
# Board configuration:
# Iteration: 34
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 35, Temperature: 70.3448
# Board configuration:
# Iteration: 35
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 36, Temperature: 69.6413
# Board configuration:
# Iteration: 36
# . . Q . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . Q . . . .
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . . . Q
#
#
# Current cost: 6.0
# Acceptance probability: 0.9717
#
# Iteration 37, Temperature: 68.9449
# Board configuration:
# Iteration: 37
# . . Q . . . . .
# . . . . Q . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . . . Q
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 38, Temperature: 68.2555
# Board configuration:
# Iteration: 38
# . . Q . . . . .
# . . . . Q . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . . . Q .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9855
#
# Iteration 39, Temperature: 67.5729
# Board configuration:
# Iteration: 39
# . . Q . . . . .
# . . . . . . Q .
# . . . . . Q . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 40, Temperature: 66.8972
# Board configuration:
# Iteration: 40
# . . Q . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 41, Temperature: 66.2282
# Board configuration:
# Iteration: 41
# . . Q . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . Q . .
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9703
#
# Iteration 42, Temperature: 65.5659
# Board configuration:
# Iteration: 42
# . Q . . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . Q . .
# . . . . Q . . .
# . . Q . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 43, Temperature: 64.9103
# Board configuration:
# Iteration: 43
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
# . . . . Q . . .
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 44, Temperature: 64.2612
# Board configuration:
# Iteration: 44
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 45, Temperature: 63.6185
# Board configuration:
# Iteration: 45
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 46, Temperature: 62.9824
# Board configuration:
# Iteration: 46
# . . Q . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9842
#
# Iteration 47, Temperature: 62.3525
# Board configuration:
# Iteration: 47
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 48, Temperature: 61.7290
# Board configuration:
# Iteration: 48
# . Q . . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9526
#
# Iteration 49, Temperature: 61.1117
# Board configuration:
# Iteration: 49
# . Q . . . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9521
#
# Iteration 50, Temperature: 60.5006
# Board configuration:
# Iteration: 50
# . Q . . . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 51, Temperature: 59.8956
# Board configuration:
# Iteration: 51
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 52, Temperature: 59.2966
# Board configuration:
# Iteration: 52
# . . . . . Q . .
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9833
#
# Iteration 53, Temperature: 58.7037
# Board configuration:
# Iteration: 53
# . . . . . Q . .
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9831
#
# Iteration 54, Temperature: 58.1166
# Board configuration:
# Iteration: 54
# . . . . . Q . .
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9662
#
# Iteration 55, Temperature: 57.5355
# Board configuration:
# Iteration: 55
# Q . . . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . Q . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 56, Temperature: 56.9601
# Board configuration:
# Iteration: 56
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . . Q . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 57, Temperature: 56.3905
# Board configuration:
# Iteration: 57
# Q . . . . . . .
# . . . . . Q . .
# . . . . Q . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9652
#
# Iteration 58, Temperature: 55.8266
# Board configuration:
# Iteration: 58
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . . . Q .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9477
#
# Iteration 59, Temperature: 55.2683
# Board configuration:
# Iteration: 59
# . . . . . Q . .
# . . . . . . Q .
# . . . . Q . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 60, Temperature: 54.7157
# Board configuration:
# Iteration: 60
# . . . . . . . Q
# . . . . . . Q .
# . . . . Q . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# Q . . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 61, Temperature: 54.1685
# Board configuration:
# Iteration: 61
# . . Q . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# Q . . . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 62, Temperature: 53.6268
# Board configuration:
# Iteration: 62
# . . Q . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# Q . . . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 63, Temperature: 53.0906
# Board configuration:
# Iteration: 63
# . . Q . . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 64, Temperature: 52.5596
# Board configuration:
# Iteration: 64
# . . Q . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
#
#
# Current cost: 4.0
# Acceptance probability: 0.9627
#
# Iteration 65, Temperature: 52.0341
# Board configuration:
# Iteration: 65
# . . Q . . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
#
#
# Current cost: 8.0
# Acceptance probability: 0.9260
#
# Iteration 66, Temperature: 51.5137
# Board configuration:
# Iteration: 66
# . . Q . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . Q . .
# Q . . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 67, Temperature: 50.9986
# Board configuration:
# Iteration: 67
# . . Q . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 68, Temperature: 50.4886
# Board configuration:
# Iteration: 68
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 69, Temperature: 49.9837
# Board configuration:
# Iteration: 69
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9802
#
# Iteration 70, Temperature: 49.4839
# Board configuration:
# Iteration: 70
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . . . Q
# . Q . . . . . .
# Q . . . . . . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.9223
#
# Iteration 71, Temperature: 48.9890
# Board configuration:
# Iteration: 71
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 8.0
# Acceptance probability: 1.0000
#
# Iteration 72, Temperature: 48.4991
# Board configuration:
# Iteration: 72
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . . Q .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 73, Temperature: 48.0141
# Board configuration:
# Iteration: 73
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 74, Temperature: 47.5340
# Board configuration:
# Iteration: 74
# . . . . . . . Q
# . . Q . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . Q .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 75, Temperature: 47.0587
# Board configuration:
# Iteration: 75
# . Q . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9790
#
# Iteration 76, Temperature: 46.5881
# Board configuration:
# Iteration: 76
# . Q . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9788
#
# Iteration 77, Temperature: 46.1222
# Board configuration:
# Iteration: 77
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 78, Temperature: 45.6610
# Board configuration:
# Iteration: 78
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 79, Temperature: 45.2044
# Board configuration:
# Iteration: 79
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9781
#
# Iteration 80, Temperature: 44.7523
# Board configuration:
# Iteration: 80
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9779
#
# Iteration 81, Temperature: 44.3048
# Board configuration:
# Iteration: 81
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 82, Temperature: 43.8618
# Board configuration:
# Iteration: 82
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9775
#
# Iteration 83, Temperature: 43.4231
# Board configuration:
# Iteration: 83
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9332
#
# Iteration 84, Temperature: 42.9889
# Board configuration:
# Iteration: 84
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
#
#
# Current cost: 7.0
# Acceptance probability: 1.0000
#
# Iteration 85, Temperature: 42.5590
# Board configuration:
# Iteration: 85
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 86, Temperature: 42.1334
# Board configuration:
# Iteration: 86
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 87, Temperature: 41.7121
# Board configuration:
# Iteration: 87
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 88, Temperature: 41.2950
# Board configuration:
# Iteration: 88
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 89, Temperature: 40.8820
# Board configuration:
# Iteration: 89
# . . . . Q . . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9758
#
# Iteration 90, Temperature: 40.4732
# Board configuration:
# Iteration: 90
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 91, Temperature: 40.0685
# Board configuration:
# Iteration: 91
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . Q .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 92, Temperature: 39.6678
# Board configuration:
# Iteration: 92
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9508
#
# Iteration 93, Temperature: 39.2711
# Board configuration:
# Iteration: 93
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 94, Temperature: 38.8784
# Board configuration:
# Iteration: 94
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9499
#
# Iteration 95, Temperature: 38.4896
# Board configuration:
# Iteration: 95
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 96, Temperature: 38.1047
# Board configuration:
# Iteration: 96
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 97, Temperature: 37.7237
# Board configuration:
# Iteration: 97
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 98, Temperature: 37.3464
# Board configuration:
# Iteration: 98
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 99, Temperature: 36.9730
# Board configuration:
# Iteration: 99
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 100, Temperature: 36.6032
# Board configuration:
# Iteration: 100
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . . Q
#
#
# Current cost: 5.0
# Acceptance probability: 0.9213
#
# Iteration 101, Temperature: 36.2372
# Board configuration:
# Iteration: 101
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 102, Temperature: 35.8748
# Board configuration:
# Iteration: 102
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 103, Temperature: 35.5161
# Board configuration:
# Iteration: 103
# Q . . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 104, Temperature: 35.1609
# Board configuration:
# Iteration: 104
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9720
#
# Iteration 105, Temperature: 34.8093
# Board configuration:
# Iteration: 105
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . Q . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9442
#
# Iteration 106, Temperature: 34.4612
# Board configuration:
# Iteration: 106
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . Q . . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.9436
#
# Iteration 107, Temperature: 34.1166
# Board configuration:
# Iteration: 107
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 108, Temperature: 33.7754
# Board configuration:
# Iteration: 108
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# Q . . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 109, Temperature: 33.4377
# Board configuration:
# Iteration: 109
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9419
#
# Iteration 110, Temperature: 33.1033
# Board configuration:
# Iteration: 110
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 111, Temperature: 32.7723
# Board configuration:
# Iteration: 111
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 112, Temperature: 32.4446
# Board configuration:
# Iteration: 112
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 113, Temperature: 32.1201
# Board configuration:
# Iteration: 113
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 114, Temperature: 31.7989
# Board configuration:
# Iteration: 114
# . . . . . . Q .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9390
#
# Iteration 115, Temperature: 31.4809
# Board configuration:
# Iteration: 115
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9384
#
# Iteration 116, Temperature: 31.1661
# Board configuration:
# Iteration: 116
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 117, Temperature: 30.8544
# Board configuration:
# Iteration: 117
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 118, Temperature: 30.5459
# Board configuration:
# Iteration: 118
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9678
#
# Iteration 119, Temperature: 30.2404
# Board configuration:
# Iteration: 119
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 120, Temperature: 29.9380
# Board configuration:
# Iteration: 120
# . . . . . . Q .
# . . Q . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9671
#
# Iteration 121, Temperature: 29.6387
# Board configuration:
# Iteration: 121
# . . . . . . Q .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9347
#
# Iteration 122, Temperature: 29.3423
# Board configuration:
# Iteration: 122
# . . . . . . Q .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . Q . .
# . Q . . . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9665
#
# Iteration 123, Temperature: 29.0488
# Board configuration:
# Iteration: 123
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 124, Temperature: 28.7584
# Board configuration:
# Iteration: 124
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 9.0
# Acceptance probability: 0.8404
#
# Iteration 125, Temperature: 28.4708
# Board configuration:
# Iteration: 125
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
#
#
# Current cost: 10.0
# Acceptance probability: 0.9655
#
# Iteration 126, Temperature: 28.1861
# Board configuration:
# Iteration: 126
# . . . . . . Q .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 127, Temperature: 27.9042
# Board configuration:
# Iteration: 127
# . . . . . . Q .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 128, Temperature: 27.6252
# Board configuration:
# Iteration: 128
# . . . . . . Q .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 129, Temperature: 27.3489
# Board configuration:
# Iteration: 129
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . Q . . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 130, Temperature: 27.0754
# Board configuration:
# Iteration: 130
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9288
#
# Iteration 131, Temperature: 26.8047
# Board configuration:
# Iteration: 131
# . . . . Q . . .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9634
#
# Iteration 132, Temperature: 26.5366
# Board configuration:
# Iteration: 132
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9274
#
# Iteration 133, Temperature: 26.2713
# Board configuration:
# Iteration: 133
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9627
#
# Iteration 134, Temperature: 26.0085
# Board configuration:
# Iteration: 134
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 135, Temperature: 25.7485
# Board configuration:
# Iteration: 135
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9253
#
# Iteration 136, Temperature: 25.4910
# Board configuration:
# Iteration: 136
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 137, Temperature: 25.2361
# Board configuration:
# Iteration: 137
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 138, Temperature: 24.9837
# Board configuration:
# Iteration: 138
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.8869
#
# Iteration 139, Temperature: 24.7339
# Board configuration:
# Iteration: 139
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9604
#
# Iteration 140, Temperature: 24.4865
# Board configuration:
# Iteration: 140
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 141, Temperature: 24.2417
# Board configuration:
# Iteration: 141
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 142, Temperature: 23.9992
# Board configuration:
# Iteration: 142
# . . . . . . Q .
# . . . . Q . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 143, Temperature: 23.7593
# Board configuration:
# Iteration: 143
# . . . . . . Q .
# . . . . Q . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# . . . Q . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 144, Temperature: 23.5217
# Board configuration:
# Iteration: 144
# Q . . . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9584
#
# Iteration 145, Temperature: 23.2864
# Board configuration:
# Iteration: 145
# Q . . . . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9580
#
# Iteration 146, Temperature: 23.0536
# Board configuration:
# Iteration: 146
# Q . . . . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9576
#
# Iteration 147, Temperature: 22.8230
# Board configuration:
# Iteration: 147
# Q . . . . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
#
#
# Current cost: 10.0
# Acceptance probability: 0.8033
#
# Iteration 148, Temperature: 22.5948
# Board configuration:
# Iteration: 148
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . Q . . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 1.0000
#
# Iteration 149, Temperature: 22.3689
# Board configuration:
# Iteration: 149
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . . . . . Q
# . Q . . . . . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.9563
#
# Iteration 150, Temperature: 22.1452
# Board configuration:
# Iteration: 150
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 151, Temperature: 21.9237
# Board configuration:
# Iteration: 151
# . . . . . . Q .
# . . Q . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9554
#
# Iteration 152, Temperature: 21.7045
# Board configuration:
# Iteration: 152
# . . . . . . Q .
# . . . Q . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . . Q
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 153, Temperature: 21.4874
# Board configuration:
# Iteration: 153
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . . Q
# . Q . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9545
#
# Iteration 154, Temperature: 21.2726
# Board configuration:
# Iteration: 154
# . . . . . . Q .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 155, Temperature: 21.0598
# Board configuration:
# Iteration: 155
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 156, Temperature: 20.8492
# Board configuration:
# Iteration: 156
# . . . . . . Q .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 157, Temperature: 20.6408
# Board configuration:
# Iteration: 157
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 158, Temperature: 20.4343
# Board configuration:
# Iteration: 158
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . Q . . .
# . . . . . . . Q
#
#
# Current cost: 6.0
# Acceptance probability: 0.8635
#
# Iteration 159, Temperature: 20.2300
# Board configuration:
# Iteration: 159
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . Q . . .
# . . . . . . . Q
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 160, Temperature: 20.0277
# Board configuration:
# Iteration: 160
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . Q . . .
# . . . . . . . Q
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 161, Temperature: 19.8274
# Board configuration:
# Iteration: 161
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 162, Temperature: 19.6292
# Board configuration:
# Iteration: 162
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 163, Temperature: 19.4329
# Board configuration:
# Iteration: 163
# . . . . . . Q .
# . . . . Q . . .
# . Q . . . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 164, Temperature: 19.2385
# Board configuration:
# Iteration: 164
# . . . . . Q . .
# . . . . Q . . .
# . Q . . . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 165, Temperature: 19.0461
# Board configuration:
# Iteration: 165
# . . . . . Q . .
# . . . . Q . . .
# . Q . . . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 166, Temperature: 18.8557
# Board configuration:
# Iteration: 166
# . . . . . Q . .
# . . Q . . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
#
#
# Current cost: 6.0
# Acceptance probability: 0.8529
#
# Iteration 167, Temperature: 18.6671
# Board configuration:
# Iteration: 167
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 168, Temperature: 18.4805
# Board configuration:
# Iteration: 168
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . Q . . .
# Q . . . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 169, Temperature: 18.2957
# Board configuration:
# Iteration: 169
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . Q . . .
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
#
#
# Current cost: 3.0
# Acceptance probability: 0.9468
#
# Iteration 170, Temperature: 18.1127
# Board configuration:
# Iteration: 170
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . Q . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 171, Temperature: 17.9316
# Board configuration:
# Iteration: 171
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.8001
#
# Iteration 172, Temperature: 17.7523
# Board configuration:
# Iteration: 172
# . . . . Q . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . . . Q . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9452
#
# Iteration 173, Temperature: 17.5747
# Board configuration:
# Iteration: 173
# . . . . Q . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
# . Q . . . . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 174, Temperature: 17.3990
# Board configuration:
# Iteration: 174
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 175, Temperature: 17.2250
# Board configuration:
# Iteration: 175
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . Q . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 176, Temperature: 17.0527
# Board configuration:
# Iteration: 176
# . . . . . . . Q
# . . . Q . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.8893
#
# Iteration 177, Temperature: 16.8822
# Board configuration:
# Iteration: 177
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 178, Temperature: 16.7134
# Board configuration:
# Iteration: 178
# . . . . . Q . .
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . . Q
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 179, Temperature: 16.5463
# Board configuration:
# Iteration: 179
# . . . . . Q . .
# . . . . . . Q .
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . . . Q
#
#
# Current cost: 5.0
# Acceptance probability: 0.9414
#
# Iteration 180, Temperature: 16.3808
# Board configuration:
# Iteration: 180
# . . . . . Q . .
# . . . . . . . Q
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 181, Temperature: 16.2170
# Board configuration:
# Iteration: 181
# . . . . . Q . .
# . . . Q . . . .
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . . Q .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9402
#
# Iteration 182, Temperature: 16.0548
# Board configuration:
# Iteration: 182
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . . . . Q .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9396
#
# Iteration 183, Temperature: 15.8943
# Board configuration:
# Iteration: 183
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 184, Temperature: 15.7353
# Board configuration:
# Iteration: 184
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9384
#
# Iteration 185, Temperature: 15.5780
# Board configuration:
# Iteration: 185
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 186, Temperature: 15.4222
# Board configuration:
# Iteration: 186
# . . . . Q . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 187, Temperature: 15.2680
# Board configuration:
# Iteration: 187
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 6.0
# Acceptance probability: 0.8216
#
# Iteration 188, Temperature: 15.1153
# Board configuration:
# Iteration: 188
# . . . . Q . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . Q . . . . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.8761
#
# Iteration 189, Temperature: 14.9641
# Board configuration:
# Iteration: 189
# . . . . Q . . .
# . . . . . . Q .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . Q . . . .
# . . Q . . . . .
#
#
# Current cost: 9.0
# Acceptance probability: 0.9354
#
# Iteration 190, Temperature: 14.8145
# Board configuration:
# Iteration: 190
# . . . . Q . . .
# . . . . . . Q .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . Q . . . . .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 191, Temperature: 14.6664
# Board configuration:
# Iteration: 191
# . . . . Q . . .
# . . . . . . Q .
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 192, Temperature: 14.5197
# Board configuration:
# Iteration: 192
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . Q . . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 193, Temperature: 14.3745
# Board configuration:
# Iteration: 193
# . . . . Q . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 0.9328
#
# Iteration 194, Temperature: 14.2307
# Board configuration:
# Iteration: 194
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . Q . . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 195, Temperature: 14.0884
# Board configuration:
# Iteration: 195
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . Q . .
# Q . . . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 0.9315
#
# Iteration 196, Temperature: 13.9476
# Board configuration:
# Iteration: 196
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . Q .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 197, Temperature: 13.8081
# Board configuration:
# Iteration: 197
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 198, Temperature: 13.6700
# Board configuration:
# Iteration: 198
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 0.9295
#
# Iteration 199, Temperature: 13.5333
# Board configuration:
# Iteration: 199
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 0.7441
#
# Iteration 200, Temperature: 13.3980
# Board configuration:
# Iteration: 200
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . Q . . . .
# . . Q . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.6885
#
# Iteration 201, Temperature: 13.2640
# Board configuration:
# Iteration: 201
# Q . . . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 1.0000
#
# Iteration 202, Temperature: 13.1313
# Board configuration:
# Iteration: 202
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 203, Temperature: 13.0000
# Board configuration:
# Iteration: 203
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 204, Temperature: 12.8700
# Board configuration:
# Iteration: 204
# Q . . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 205, Temperature: 12.7413
# Board configuration:
# Iteration: 205
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 206, Temperature: 12.6139
# Board configuration:
# Iteration: 206
# . . . . . Q . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# Q . . . . . . .
# . . Q . . . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 207, Temperature: 12.4878
# Board configuration:
# Iteration: 207
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 208, Temperature: 12.3629
# Board configuration:
# Iteration: 208
# . . . . . . Q .
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 0.9223
#
# Iteration 209, Temperature: 12.2393
# Board configuration:
# Iteration: 209
# . . . . . Q . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
#
#
# Current cost: 0
# Acceptance probability: 1.0000
#
# Solution found!
# Iteration: 209
# . . . . . Q . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
#
#
# Runtime in seconds: 1.128502607345581
