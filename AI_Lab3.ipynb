# %%
print("Akanksha Singa")
print("1BM22CS027")

def misplaced_tiles(state, goal):
    return sum(1 for i in range(3) for j in range(3) if state[i][j] != goal[i][j] and state[i][j] != 0)

def get_neighbors(state):
    neighbors = []
    blank = [(i, j) for i in range(3) for j in range(3) if state[i][j] == 0][0]
    possible_moves = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    x, y = blank

    for dx, dy in possible_moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = [row[:] for row in state]
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)

    return neighbors

def print_iteration(state, g, h):
    f = g + h
    print(f"G(N): {g}, H(N): {h}, F(N): {f} for state:")
    for row in state:
        print(row)
    print()

def astar_misplaced(start, goal):
    open_list = [(start, 0, [])]
    visited = set()

    while open_list:
        current, g, path = open_list.pop(0)
        path = path + [current]

        h = misplaced_tiles(current, goal)
        f = g + h

        print_iteration(current, g, h)  # Print each iteration's G, H, F, and state

        if current == goal:
            print("Solution Found:")
            print_iteration(current, g, h)
            return g

        for neighbor in get_neighbors(current):
            neighbor_tuple = tuple(map(tuple, neighbor))
            if neighbor_tuple not in visited:
                visited.add(neighbor_tuple)
                open_list.append((neighbor, g + 1, path))

        open_list.sort(key=lambda x: x[1] + misplaced_tiles(x[0], goal))

    return -1

start = [[2, 8, 3], [1, 6, 4], [7, 0, 5]]
goal = [[1, 2, 3], [8, 0, 4], [7, 6, 5]]
astar_misplaced(start, goal)
# Out:
# Akanksha Singa
# 1BM22CS027
# G(N): 0, H(N): 4, F(N): 4 for state:
# [2, 8, 3]
# [1, 6, 4]
# [7, 0, 5]
#
# G(N): 1, H(N): 3, F(N): 4 for state:
# [2, 8, 3]
# [1, 0, 4]
# [7, 6, 5]
#
# G(N): 2, H(N): 3, F(N): 5 for state:
# [2, 0, 3]
# [1, 8, 4]
# [7, 6, 5]
#
# G(N): 2, H(N): 3, F(N): 5 for state:
# [2, 8, 3]
# [0, 1, 4]
# [7, 6, 5]
#
# G(N): 3, H(N): 2, F(N): 5 for state:
# [0, 2, 3]
# [1, 8, 4]
# [7, 6, 5]
#
# G(N): 4, H(N): 1, F(N): 5 for state:
# [1, 2, 3]
# [0, 8, 4]
# [7, 6, 5]
#
# G(N): 5, H(N): 0, F(N): 5 for state:
# [1, 2, 3]
# [8, 0, 4]
# [7, 6, 5]
#
# Solution Found:
# G(N): 5, H(N): 0, F(N): 5 for state:
# [1, 2, 3]
# [8, 0, 4]
# [7, 6, 5]
# 5

# %%
print("Akanksha Singa")
print("1BM22CS027")

def manhattan_distance(state, goal):
    distance = 0
    for i in range(3):
        for j in range(3):
            if state[i][j] != 0:
                goal_x, goal_y = [(x, y) for x in range(3) for y in range(3) if goal[x][y] == state[i][j]][0]
                distance += abs(i - goal_x) + abs(j - goal_y)
    return distance

def get_neighbors(state):
    neighbors = []
    blank = [(i, j) for i in range(3) for j in range(3) if state[i][j] == 0][0]
    possible_moves = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    x, y = blank

    for dx, dy in possible_moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = [row[:] for row in state]
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)

    return neighbors

def print_iteration(state, g, h):
    f = g + h
    print(f"G(N): {g}, H(N): {h}, F(N): {f} for state:")
    for row in state:
        print(row)
    print()

def astar_manhattan(start, goal):
    open_list = [(start, 0, [])]
    visited = set()

    while open_list:
        current, g, path = open_list.pop(0)
        path = path + [current]

        h = manhattan_distance(current, goal)
        f = g + h

        print_iteration(current, g, h)  # Print G, H, F for each iteration

        if current == goal:
            print("Solution Found:")
            print_iteration(current, g, h)  # Print the solution's costs
            return g

        for neighbor in get_neighbors(current):
            neighbor_tuple = tuple(map(tuple, neighbor))
            if neighbor_tuple not in visited:
                visited.add(neighbor_tuple)
                open_list.append((neighbor, g + 1, path))

        open_list.sort(key=lambda x: x[1] + manhattan_distance(x[0], goal))

    return -1

start = [[2, 8, 3], [1, 6, 4], [0, 7, 5]]
goal = [[1, 2, 3], [8, 0, 4], [7, 6, 5]]
astar_manhattan(start, goal)
# Out:
# Akanksha Singa
# 1BM22CS027
# G(N): 0, H(N): 6, F(N): 6 for state:
# [2, 8, 3]
# [1, 6, 4]
# [0, 7, 5]
#
# G(N): 1, H(N): 5, F(N): 6 for state:
# [2, 8, 3]
# [1, 6, 4]
# [7, 0, 5]
#
# G(N): 2, H(N): 4, F(N): 6 for state:
# [2, 8, 3]
# [1, 0, 4]
# [7, 6, 5]
#
# G(N): 3, H(N): 3, F(N): 6 for state:
# [2, 0, 3]
# [1, 8, 4]
# [7, 6, 5]
#
# G(N): 4, H(N): 2, F(N): 6 for state:
# [0, 2, 3]
# [1, 8, 4]
# [7, 6, 5]
#
# G(N): 5, H(N): 1, F(N): 6 for state:
# [1, 2, 3]
# [0, 8, 4]
# [7, 6, 5]
#
# G(N): 6, H(N): 0, F(N): 6 for state:
# [1, 2, 3]
# [8, 0, 4]
# [7, 6, 5]
#
# Solution Found:
# G(N): 6, H(N): 0, F(N): 6 for state:
# [1, 2, 3]
# [8, 0, 4]
# [7, 6, 5]
# 6
